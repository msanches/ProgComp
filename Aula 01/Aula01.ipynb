# %% [markdown]
# # <font size='14'>Programação de Computadores</font>
#
# <h1> Aula 01: Introdução à Programação de Computadores</h1>
#
# > Pressione as teclas <b>SHIFT</b> e <b>ENTER</b> para executar o código em uma célula ou pressione o botão Play

# %% [markdown]
# # Olá mundo

# %%
print("Olá mundo")

# %% [markdown]
# # Primeiro exemplo

# %%
print("Tabuada do 2")
for i in range(11):
  print( 2 * i)

# %% [markdown]
# # Comandos de entrada e saída em Python

# %%
# Olá mundo!
print("Olá mundo!!!")
# Out:
# Olá mundo!!!

# %%
#Primeiro exemplo
a = input("Digite seu nome ")
print("Olá ",  a, " sejam bem-vindo!!!")

# %% [markdown]
# # Melhorando nosso primeiro exemplo

# %%
a = int(input("Qual a tabuada desejada (1-10)? "))
for i in range(11):
  print( a, "x", i, "=", a*i)
